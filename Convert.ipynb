# %% [markdown]
# ## **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## **Convert**

# %%
# !jupyter nbconvert --to python '/content/drive/MyDrive/ECG ML/Dataset.ipynb'
# !jupyter nbconvert --to python '/content/drive/MyDrive/ECG ML/Model.ipynb'
# !jupyter nbconvert --to python '/content/drive/MyDrive/ECG ML/Test.ipynb'
